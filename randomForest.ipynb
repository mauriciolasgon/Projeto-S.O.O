# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error

# %%
arquivo="data\dataset.csv"
dataset=pd.read_csv(arquivo)
dataset.head(10)

symptoms="data\Symptom-severity.csv"
symptoms=pd.read_csv(symptoms)

data=pd.DataFrame(index=dataset["Disease"],columns=symptoms["Symptom"])


data
# Out:
# Symptom                                 itching skin_rash  \
# Disease
# Fungal infection                            NaN       NaN
# Fungal infection                            NaN       NaN
# Fungal infection                            NaN       NaN
# Fungal infection                            NaN       NaN
# Fungal infection                            NaN       NaN
# ...                                         ...       ...
# (vertigo) Paroymsal  Positional Vertigo     NaN       NaN
# Acne                                        NaN       NaN
# Urinary tract infection                     NaN       NaN
# Psoriasis                                   NaN       NaN
# Impetigo                                    NaN       NaN
#
# Symptom                                 nodal_skin_eruptions  \
# Disease
# Fungal infection                                         NaN
# Fungal infection                                         NaN
# Fungal infection                                         NaN
# ...

# %%
dataset.head(20)
# Out:
#              Disease             Symptom_1              Symptom_2  \
# 0   Fungal infection               itching              skin_rash
# 1   Fungal infection             skin_rash   nodal_skin_eruptions
# 2   Fungal infection               itching   nodal_skin_eruptions
# 3   Fungal infection               itching              skin_rash
# 4   Fungal infection               itching              skin_rash
# 5   Fungal infection             skin_rash   nodal_skin_eruptions
# 6   Fungal infection               itching   nodal_skin_eruptions
# 7   Fungal infection               itching              skin_rash
# 8   Fungal infection               itching              skin_rash
# 9   Fungal infection               itching              skin_rash
# 10           Allergy   continuous_sneezing              shivering
# 11           Allergy             shivering                 chills
# 12           Allergy   continuous_sneezing                 chills
# ...

# %%
x=dataset.drop("Disease",axis=1)

linha_data,coluna_data=data.shape

linha_x,coluna_x=x.shape

for sintoma,j in zip(data,range(coluna_data)):
    for sintomas,i in zip(x.iterrows(),range(linha_x)):
        if(sintomas[1].str.contains(sintoma,case=False).any()):
            data.iloc[i][j]=1
        else:
            data.iloc[i][j]=0






data.head(20)
# Out:
# C:\Users\maugo\AppData\Local\Temp\ipykernel_16124\3726055011.py:10: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data.iloc[i][j]=1
# C:\Users\maugo\AppData\Local\Temp\ipykernel_16124\3726055011.py:12: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   data.iloc[i][j]=0
# C:\Users\maugo\AppData\Local\Temp\ipykernel_16124\3726055011.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   if(sintomas[1].str.contains(sintoma,case=False).any()):

# %%
y=dataset["Disease"]

le=preprocessing.LabelEncoder()

#for colum in x.columns:
    #x[colum] = le.fit_transform(x[colum])

y=le.fit_transform(y)

# %%
Xtr,Xval,Ytr,Yval=train_test_split(data,y,test_size=0.6,random_state=0)

floresta=RandomForestRegressor(n_estimators=300,random_state=0)

floresta.fit(Xtr,Ytr)


p=floresta.predict(Xval)


np.sqrt(mean_squared_error(Yval,p))
# Out:
# 0.8928305074962037
